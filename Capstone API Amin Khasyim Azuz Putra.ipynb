# %% [markdown]
# # Background
#
# Sebagai data scientist, tugas utama kita akan selalu bergelut dengan data. Namun, selama ini, apakah kita sadar darimana data kita berasal? bagaimana data kita dikumpulkan? dsb dsb? Untuk menjadi seorang data scientist yang baik, saya rasa pengetahuan dan pengalmaan dalam mengumpulkan data cukup penting. Apakah anda pernah kesulitan dalam mencari data? apakah anda pernah kesulitan dalam melakukan pelabelan data? apakah kalian percaya bahwa data seharusnya gratis dan mudah untuk diakses. It's Data for Democracy!
#
# Untuk membuat data dapat diakses oleh semua orang, pihak penyedia jasa juga harus memberikan batasan guna mengurangi penggunaan berlebihan dan penyalahgunaan data oleh pihak-pihak yang tidak bertanggungjawab. Untuk menanggulangi permasalahn ini, kita bisa memanfaatkan teknologi API (Application Program Interface). Dengan API, kita dapat mengatur bagaimana data kita dapat diakses secara umum.
#
# Dalam Capstone kali ini, kita akan mencoba membuat API menggunakan python + flask agar data kita dapat diakses secara umum. Secara konsep, kita akan membangun aplikasi python menggunakan flask yang dapat mengatur, membaa, dan mengirimkan response terhadap request user.

# %% [markdown]
# **Data yang digunakan:**
# - books_c.csv
#
# **Environtments:**
# - python
# - pandas
# - flask
# - gunicorn
#
#
# **Goals**
# 1. Berhasil membuat Flask APP yang berfungsi sebagai API yang memberikan data dalam format JSON
# 2. Berhasil membuat minimal 2 endpoint statis (atau lebih) dan 1 endpoint dinamis(atau lebih) menggunakan routing
# 3. Berhasil melakukan deployment Flask APP ke Heroku
#
# *Notes: menggunakan endpoints yang sudah dicontohkan tidak akan dihitung sebagai endpoint hasil kerja capstone*

# %% [markdown]
# # Membangun API Python dalam 6 menit
# *Disclaimer: Course ini adalah course singkat untuk memperkenalkan student kedalam dunia **backend**. Akan ada sangat banyak kekurangan dari konsep API yang ada saat ini. Untuk kemudahan, kita hanya akan membahas konsep dasar dari API dan dan mewujudkannya dalam bentuk Flask App

# %% [markdown]
# Kita akan mencoba membangun Flask App sebagai API, oleh karena itu jika belum memiliki library `Flask`, silakan install menggunakan `pip install flask`. Berikut adalah beberapa library yang akan kita butuhkan. Cobalah import library tersebut sebelum menginstallnya.

# %%
# !pip install flask
# !pip install pandas
# !pip install requests
# !pip install gunicorn

# %%
import flask

# %%
import pandas as pd

# %%
import requests

# %%
import gunicorn

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.float_format = '{:,}'.format

# %%
books = pd.read_csv('data/books_c.csv',index_col=0)

# %%
books.head()
# Out:
#                                                     title       authors  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...  J.K. Rowling
# 2       Harry Potter and the Order of the Phoenix (Har...  J.K. Rowling
# 3       Harry Potter and the Sorcerer's Stone (Harry P...  J.K. Rowling
# 4       Harry Potter and the Chamber of Secrets (Harry...  J.K. Rowling
# 5       Harry Potter and the Prisoner of Azkaban (Harr...  J.K. Rowling
#
#         average_rating        isbn         isbn13 language_code  # num_pages  \
# bookID
# 1                 4.56  0439785960  9780439785969           eng          652
# 2                 4.49  0439358078  9780439358071           eng          870
# 3                 4.47  0439554934  9780439554930           eng          320
# 4                 4.41  0439554896  9780439554893           eng          352
# 5                 4.55  043965548X  9780439655484           eng          435
#
#         ratings_count  text_reviews_count
# bookID
# 1             1944099               26249
# 2             1996446               27613
# 3             5629932               70390
# 4                6267                 272
# 5             2149872               33964

# %%
#Get to know the data first!details below!
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13714 entries, 1 to 47709
# Data columns (total 9 columns):
# title                 13714 non-null object
# authors               13714 non-null object
# average_rating        13714 non-null float64
# isbn                  13714 non-null object
# isbn13                13714 non-null int64
# language_code         13714 non-null object
# # num_pages           13714 non-null int64
# ratings_count         13714 non-null int64
# text_reviews_count    13714 non-null int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 1.0+ MB

# %%
# The type of data there are 
# - 4 Object
# - 5 Int64
# - 1 Float
books.dtypes
# Out:
# title                  object
# authors                object
# average_rating        float64
# isbn                   object
# isbn13                  int64
# language_code          object
# # num_pages             int64
# ratings_count           int64
# text_reviews_count      int64
# dtype: object

# %%
#No Missing Value
#miss_val= 
books.isna().sum()
#miss_val.to_csv('missval.csv')
# Out:
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
# # num_pages           0
# ratings_count         0
# text_reviews_count    0
# dtype: int64

# %%
#No Duplicate Value
books.duplicated().sum()
#dup_val.to_csv('dupval.csv')
# Out:
# 0

# %%
#The data frame contains a 13714 coulumn & 10 Row. the shape output are the same as DF
books.shape
# Out:
# (13714, 9)

# %%
#The size of the data is 1.0 MB+
books.size
# Out:
# 123426

# %%
Table_4 = books[['authors','average_rating','language_code','text_reviews_count']]
Table_4
# Out:
#                               authors  average_rating language_code  \
# bookID
# 1                        J.K. Rowling            4.56           eng
# 2                        J.K. Rowling            4.49           eng
# 3                        J.K. Rowling            4.47           eng
# 4                        J.K. Rowling            4.41           eng
# 5                        J.K. Rowling            4.55           eng
# ...                               ...             ...           ...
# 47699   Neil Gaiman-Teddy Kristiansen            3.82           eng
# 47700         Neil Gaiman-Dave McKean            3.72           eng
# 47701      Neil Gaiman-Michael Reaves            3.53         en-US
# 47708     Brian Froud-Jessica Macbeth            4.43           eng
# 47709                     Brian Froud            4.29           eng
#
#         text_reviews_count
# bookID
# 1                    26249
# 2                    27613
# 3                    70390
# 4                      272
# 5                    33964
# ...                    ...
# 47699                 1060
# 47700                  361
# 47701                 1485
# 47708                   38
# 47709                   33
#
# [13714 rows x 4 columns]

# %%
Table_4.to_csv('choosen_table.csv')

# %%
#from original file i want to know who is most mention author in books_c.csv data frame
books['authors'].value_counts()
# Out:
# Agatha Christie                 69
# Stephen King                    66
# Orson Scott Card                48
# Rumiko Takahashi                46
# P.G. Wodehouse                  42
#                                 ..
# Elizabeth A. Schultz             1
# Lawrence Sutin                   1
# Virgil-G.P. Goold                1
# Boethius-Richard H. Green        1
# C.S. Lewis-Ana Falcão Bastos     1
# Name: authors, Length: 7599, dtype: int64

# %%
#Make a condition for most mention author in data frame
author = books[(books.authors == 'Agatha Christie')]

# %%
#make another copy to assign a new variable
book_authr = books.copy()

# %%
book_authr = author

# %%
book_authr['average_rating']=book_authr['average_rating'].round(1)
book_authr
# Out:
# <ipython-input-30-065a547379ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_authr['average_rating']=book_authr['average_rating'].round(1)
#                                                     title          authors  \
# bookID
# 16297            Cards on the Table (Hercule Poirot  #15)  Agatha Christie
# 16298             A Murder Is Announced (Miss Marple  #5)  Agatha Christie
# 16299                            And Then There Were None  Agatha Christie
# 16300                   Sleeping Murder (Miss Marple #13)  Agatha Christie
# 16303                    The Hollow (Hercule Poirot  #26)  Agatha Christie
# ...                                                   ...              ...
# 37563                                        Mörderblumen  Agatha Christie
# 37574                                  The Mirror Crack'd  Agatha Christie
# 37575                                   Dead Man's Mirror  Agatha Christie
# 37582   Miss Marple Meets Murder: The Mirror Crack'd /...  Agatha Christie
# 39954   Dame Agatha Abroad: Murder on the Orient Expre...  Agatha Christie
#
#         average_rating        isbn         isbn13 language_code  # num_pages  \
# bookID
# 16297              3.9  0425205959  9780425205952           eng          324
# 16298              4.0  1579126294  9781579126292           eng          288
# 16299              4.2  0312330871  9780312330873           eng          264
# 16300              3.9  0002317850  9780002317856           eng          242
# 16303              3.8  0007121024  9780007121021           eng          384
# ...                ...         ...            ...           ...          ...
# 37563              3.7  3502509131  9783502509134           ger          158
# 37574              3.9  0553350153  9780553350159           eng          212
# 37575              3.8  0553350749  9780553350746           eng          233
# 37582              4.2  2731800097  9780800327101           eng          661
# 39954              4.0  0739460870  9780739460870           eng          568
#
#         ratings_count  text_reviews_count
# bookID
# 16297           23561                 936
# 16298           31050                1097
# 16299          558832               16793
# 16300           18550                 811
# 16303           13022                 606
# ...               ...                 ...
# 37563               7                   0
# 37574              62                  10
# 37575              30                   1
# 37582             172                   9
# 39954              43                   6
#
# [69 rows x 9 columns]

# %%
book_authr['language_code'].value_counts()
languageu_cate = book_authr['language_code'].astype('category')
#book_authr['language_code'] = book_authr['language_code'].astype('category')
languageu_cate
# Out:
# bookID
# 16297    eng
# 16298    eng
# 16299    eng
# 16300    eng
# 16303    eng
#         ...
# 37563    ger
# 37574    eng
# 37575    eng
# 37582    eng
# 39954    eng
# Name: language_code, Length: 69, dtype: category
# Categories (4, object): [en-GB, en-US, eng, ger]

# %%
languageu_cate.to_csv('language_cat.csv')

# %%
#Frequency for know the how many average_rating for book_authr df
freq_rating = pd.crosstab(
    index=book_authr['average_rating'], 
    columns="count").sort_values('count',ascending =False)
freq_rating
# Out:
# col_0           count
# average_rating
# 3.8                18
# 4.0                15
# 3.9                13
# 4.2                 9
# 3.7                 7
# 3.6                 3
# 4.3                 2
# 4.1                 1
# 4.4                 1

# %%
freq_rating.to_csv('freq_rating.csv')

# %%
book_authr
# Out:
#                                                     title          authors  \
# bookID
# 16297            Cards on the Table (Hercule Poirot  #15)  Agatha Christie
# 16298             A Murder Is Announced (Miss Marple  #5)  Agatha Christie
# 16299                            And Then There Were None  Agatha Christie
# 16300                   Sleeping Murder (Miss Marple #13)  Agatha Christie
# 16303                    The Hollow (Hercule Poirot  #26)  Agatha Christie
# ...                                                   ...              ...
# 37563                                        Mörderblumen  Agatha Christie
# 37574                                  The Mirror Crack'd  Agatha Christie
# 37575                                   Dead Man's Mirror  Agatha Christie
# 37582   Miss Marple Meets Murder: The Mirror Crack'd /...  Agatha Christie
# 39954   Dame Agatha Abroad: Murder on the Orient Expre...  Agatha Christie
#
#         average_rating        isbn         isbn13 language_code  # num_pages  \
# bookID
# 16297              3.9  0425205959  9780425205952           eng          324
# 16298              4.0  1579126294  9781579126292           eng          288
# 16299              4.2  0312330871  9780312330873           eng          264
# 16300              3.9  0002317850  9780002317856           eng          242
# 16303              3.8  0007121024  9780007121021           eng          384
# ...                ...         ...            ...           ...          ...
# 37563              3.7  3502509131  9783502509134           ger          158
# 37574              3.9  0553350153  9780553350159           eng          212
# 37575              3.8  0553350749  9780553350746           eng          233
# 37582              4.2  2731800097  9780800327101           eng          661
# 39954              4.0  0739460870  9780739460870           eng          568
#
#         ratings_count  text_reviews_count
# bookID
# 16297           23561                 936
# 16298           31050                1097
# 16299          558832               16793
# 16300           18550                 811
# 16303           13022                 606
# ...               ...                 ...
# 37563               7                   0
# 37574              62                  10
# 37575              30                   1
# 37582             172                   9
# 39954              43                   6
#
# [69 rows x 9 columns]

# %%
#doing stack, even though the output is series, we can see glimpse of a df be more orginazed because sort by book id
stack_authr = book_authr.stack()
stack_authr
# Out:
# bookID
# 16297   title                 Cards on the Table (Hercule Poirot  #15)
#         authors                                        Agatha Christie
#         average_rating                                             3.9
#         isbn                                                0425205959
#         isbn13                                           9780425205952
#                                                 ...
# 39954   isbn13                                           9780739460870
#         language_code                                              eng
#         # num_pages                                                568
#         ratings_count                                               43
#         text_reviews_count                                           6
# Length: 621, dtype: object

# %%
stack_authr.to_csv('author_stack.csv')
# Out:
# <ipython-input-133-d6b63b11b8d1>:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   stack_authr.to_csv('author_stack.csv')

# %%
#unstack is personally not my fav for this. the output in index is title, not so organized compare to stack.
unstack_authr = book_authr.unstack()
unstack_authr
# Out:
#                     bookID
# title               16297     Cards on the Table (Hercule Poirot  #15)
#                     16298      A Murder Is Announced (Miss Marple  #5)
#                     16299                     And Then There Were None
#                     16300            Sleeping Murder (Miss Marple #13)
#                     16303             The Hollow (Hercule Poirot  #26)
#                                                 ...
# text_reviews_count  37563                                            0
#                     37574                                           10
#                     37575                                            1
#                     37582                                            9
#                     39954                                            6
# Length: 621, dtype: object

# %%
unstack_authr.to_csv('unstack_author.csv')
# Out:
# <ipython-input-135-831979ea0729>:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   unstack_authr.to_csv('unstack_author.csv')

# %%
#Melt, the output are same as book_authr df with 69 rows, the difference is the column is only 2 the variable and value
book_authr.melt(value_vars=['title'])
# Out:
#    variable                                              value
# 0     title           Cards on the Table (Hercule Poirot  #15)
# 1     title            A Murder Is Announced (Miss Marple  #5)
# 2     title                           And Then There Were None
# 3     title                  Sleeping Murder (Miss Marple #13)
# 4     title                   The Hollow (Hercule Poirot  #26)
# ..      ...                                                ...
# 64    title                                       Mörderblumen
# 65    title                                 The Mirror Crack'd
# 66    title                                  Dead Man's Mirror
# 67    title  Miss Marple Meets Murder: The Mirror Crack'd /...
# 68    title  Dame Agatha Abroad: Murder on the Orient Expre...
#
# [69 rows x 2 columns]

# %%
language = pd.crosstab(index=book_authr['language_code'], 
            columns='sum', 
            values=book_authr['ratings_count'],
            aggfunc='sum')
language
# Out:
# col_0              sum
# language_code
# en-GB               85
# en-US               83
# eng            1766695
# ger                 63

# %%
lang_group = language.groupby(['language_code']).sum()#.plot.bar()
lang_group.to_csv('language_group.csv')

# %%
pd.crosstab(index=book_authr['authors'],
            columns=[book_authr['language_code'], ['authors']],
            values=book_authr['text_reviews_count'],
            aggfunc='median')
# Out:
# language_code     en-GB   en-US     eng     ger
# col_1           authors authors authors authors
# authors
# Agatha Christie     7.0     4.0   488.0     1.5

# %%
book_authr.to_csv('book_author.csv')

# %%
#the most commong book languange is english, \
#so i just use condition to get all the information for the book using the english languange
#books['languange_code'].value_counts()
#condition = books[(books.language_code == 'eng')]

# %%
#Make a copy, so i can restart again, again and again!
book_eng = books.copy()

# %%
book_eng.head()
book_eng['average_rating']=book_eng['average_rating'].round(1)
#book_eng = condition

# %%
#Create a second condition for book rating with more than 4.0
condition2 = book_eng[(book_eng.average_rating > 4.0)]

# %%
#book_eng = condition2
book_eng
# Out:
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 3       Harry Potter and the Sorcerer's Stone (Harry P...
# 4       Harry Potter and the Chamber of Secrets (Harry...
# 5       Harry Potter and the Prisoner of Azkaban (Harr...
# ...                                                   ...
# 47699                                      M Is for Magic
# 47700                                        Black Orchid
# 47701                         InterWorld (InterWorld  #1)
# 47708                                 The Faeries' Oracle
# 47709                       The World of The Dark Crystal
#
#                               authors  average_rating        isbn  \
# bookID
# 1                        J.K. Rowling             4.6  0439785960
# 2                        J.K. Rowling             4.5  0439358078
# 3                        J.K. Rowling             4.5  0439554934
# 4                        J.K. Rowling             4.4  0439554896
# 5                        J.K. Rowling             4.6  043965548X
# ...                               ...             ...         ...
# 47699   Neil Gaiman-Teddy Kristiansen             3.8  0061186422
# 47700         Neil Gaiman-Dave McKean             3.7  0930289552
# 47701      Neil Gaiman-Michael Reaves             3.5  0061238961
# 47708     Brian Froud-Jessica Macbeth             4.4  0743201116
# 47709                     Brian Froud             4.3  1862056242
#
#                isbn13 language_code  # num_pages  ratings_count  \
# bookID
# 1       9780439785969           eng          652        1944099
# 2       9780439358071           eng          870        1996446
# 3       9780439554930           eng          320        5629932
# 4       9780439554893           eng          352           6267
# 5       9780439655484           eng          435        2149872
# ...               ...           ...          ...            ...
# 47699   9780061186424           eng          260          11317
# 47700   9780930289553           eng          160           8710
# 47701   9780061238963         en-US          239          14334
# 47708   9780743201117           eng          224           1550
# 47709   9781862056244           eng          132           3572
#
#         text_reviews_count
# bookID
# 1                    26249
# 2                    27613
# 3                    70390
# 4                      272
# 5                    33964
# ...                    ...
# 47699                 1060
# 47700                  361
# 47701                 1485
# 47708                   38
# 47709                   33
#
# [13714 rows x 9 columns]

# %%
pd.crosstab(index=book_eng['average_rating'], columns="count").sort_values("count", ascending = False).head()
# Out:
# col_0           count
# average_rating
# 4.0              2251
# 3.8              1837
# 3.9              1728
# 4.1              1605
# 4.2              1535

# %%
#book_eng['authors'].value_counts()

# %%
book_eng[(book_eng.authors == 'P.G. Wodehouse')]
# Out:
#                                                     title         authors  \
# bookID
# 12550               Stiff Upper Lip  Jeeves (Jeeves  #13)  P.G. Wodehouse
# 16374                          The Most of P.G. Wodehouse  P.G. Wodehouse
# 16376                    Full Moon (Blandings Castle  #7)  P.G. Wodehouse
# 16377             How Right You Are  Jeeves (Jeeves  #12)  P.G. Wodehouse
# 16379               Life With Jeeves (Jeeves  #6  2  & 4)  P.G. Wodehouse
# 16384                                        Spring Fever  P.G. Wodehouse
# 16385                     Lord Emsworth Acts for the Best  P.G. Wodehouse
# 16387                       Carry on  Jeeves (Jeeves  #3)  P.G. Wodehouse
# 16388   Lord Emsworth and Others (Blandings Castle  #5.5)  P.G. Wodehouse
# 16390                      The Mating Season (Jeeves  #9)  P.G. Wodehouse
# 16392                      Thank You  Jeeves (Jeeves  #5)  P.G. Wodehouse
# 16393                                           Big Money  P.G. Wodehouse
# 16394                                Much Obliged  Jeeves  P.G. Wodehouse
# 16396                  The Inimitable Jeeves (Jeeves  #2)  P.G. Wodehouse
# 16400                                   Money in the Bank  P.G. Wodehouse
# 16401                             The Luck of the Bodkins  P.G. Wodehouse
# 16415   Leave It to Psmith (Psmith  #4 ; Blandings Cas...  P.G. Wodehouse
# 18016                                     Mulliner Nights  P.G. Wodehouse
# 18017                                   Life at Blandings  P.G. Wodehouse
# 18018                                   Jill the Reckless  P.G. Wodehouse
# 18025              Something Fresh (Blandings Castle  #1)  P.G. Wodehouse
# 18027                            The Clicking of Cuthbert  P.G. Wodehouse
# 18029                       Ring for Jeeves (Jeeves  #10)  P.G. Wodehouse
# 18031                                             Ukridge  P.G. Wodehouse
# 18032         Jeeves and the Tie That Binds (Jeeves  #14)  P.G. Wodehouse
# 18035                       Right Ho  Jeeves (Jeeves  #6)  P.G. Wodehouse
# 18041                               Mr. Mulliner Speaking  P.G. Wodehouse
# 18042                                        Laughing Gas  P.G. Wodehouse
# 18045                  The World of Jeeves (Jeeves  #2-4)  P.G. Wodehouse
# 18047                             The Adventures of Sally  P.G. Wodehouse
# 18053                                   Meet Mr. Mulliner  P.G. Wodehouse
# 18055                            Eggs  Beans And Crumpets  P.G. Wodehouse
# 18057                                A Damsel in Distress  P.G. Wodehouse
# 18061   Uncle Fred in the Springtime (Blandings Castle...  P.G. Wodehouse
# 18064                           The World of Mr. Mulliner  P.G. Wodehouse
# 18067                                       Cocktail Time  P.G. Wodehouse
# 18073                  Jeeves in the Offing (Jeeves  #12)  P.G. Wodehouse
# 18074          Jeeves and The Feudal Spirit (Jeeves  #11)  P.G. Wodehouse
# 18077                                      Piccadilly Jim  P.G. Wodehouse
# 18081                     Joy in the Morning (Jeeves  #8)  P.G. Wodehouse
# 18089                      The Mating Season (Jeeves  #9)  P.G. Wodehouse
# 18098                             Indiscretions of Archie  P.G. Wodehouse
#
#         average_rating        isbn         isbn13 language_code  # num_pages  \
# bookID
# 12550              4.3  184159105X  9781841591056           eng          211
# 16374              4.5  0743203585  9780743203586           eng          701
# 16376              4.2  1585678368  9781585678365           eng          272
# 16377              4.2  0743203593  9780743203593           eng          206
# 16379              4.4  0140059024  9780140059021           eng          557
# 16384              4.1  158567575X  9781585675753           eng          276
# 16385              4.1  0141185740  9780141185743           eng          182
# 16387              4.3  1585673927  9781585673926           eng          273
# 16388              4.2  1585672777  9781585672776           eng          268
# 16390              4.3  1585672319  9781585672318           eng          272
# 16392              4.2  1585674346  9781585674343           eng          263
# 16393              3.9  014000937X  9780140009378           eng          288
# 16394              4.2  1585675261  9781585675265           eng          208
# 16396              4.2  0140284125  9780140284126           eng          240
# 16400              4.2  1585676578  9781585676576           eng          290
# 16401              4.1  1585673366  9781585673360           eng          358
# 16415              4.3  1400079608  9781400079605         en-US          328
# 18016              4.1  1400079616  9781400079612           eng          240
# 18017              4.3  0140059032  9780140059038         en-US          608
# 18018              4.0  1585676608  9781585676606           eng          290
# 18025              4.2  1585676586  9781585676583           eng          284
# 18027              3.9  1406929980  9781406929980           eng          162
# 18029              4.0  1585675245  9781585675241           eng          208
# 18031              3.9  1585674796  9781585674794           eng          272
# 18032              4.2  0743203623  9780743203623         en-US          205
# 18035              4.3  140690483X  9781406904833           eng          224
# 18041              4.0  1841591386  9781841591384         en-US          232
# 18042              3.9  1585672327  9781585672325           eng          286
# 18045              4.5  0060972440  9780060972448           eng          654
# 18047              3.8  1426423705  9781426423703         en-US          232
# 18053              4.1  1585672750  9781585672752           eng          203
# 18055              4.1  1841591068  9781841591063           eng          224
# 18057              4.1  1406953210  9781406953213           eng          216
# 18061              4.2  1841591300  9781841591308           eng          288
# 18064              4.3  0140281703  9780140281705           eng          624
# 18067              4.1  1585675741  9781585675746           eng          304
# 18073              4.2  1841591165  9781841591162           eng          208
# 18074              4.3  1841591017  9781841591018           eng          240
# 18077              4.0  1585676160  9781585676163           eng          302
# 18081              4.4  1841591157  9781841591155           eng          296
# 18089              4.3  1841591076  9781841591070           eng          272
# 18098              3.9  0742632598  9780742632592           eng          215
#
#         ratings_count  text_reviews_count
# bookID
# 12550            6720                 296
# 16374            1845                 103
# 16376            1769                 124
# 16377            2690                 148
# 16379            3143                 140
# 16384             468                  28
# 16385             187                  11
# 16387           14989                 725
# 16388            1057                  71
# 16390            4394                 266
# 16392            5681                 306
# 16393            1069                  69
# 16394             612                  55
# 16396            7430                 317
# 16400             308                  24
# 16401            1238                  76
# 16415            3429                 235
# 18016            1144                  76
# 18017            2613                  46
# 18018             627                  78
# 18025            5041                 365
# 18027               6                   2
# 18029            2660                 171
# 18031             987                  80
# 18032            2717                 127
# 18035            8206                 445
# 18041            1453                  42
# 18042            1672                 127
# 18045            2291                 134
# 18047              10                   0
# 18053            1162                  78
# 18055             874                  60
# 18057            3385                 337
# 18061            1693                 106
# 18064             338                  29
# 18067             644                  50
# 18073              26                   4
# 18074              23                   1
# 18077            2585                 174
# 18081              37                   0
# 18089              57                   2
# 18098             664                  73

# %% [markdown]
# - Create a third condition and new var with P.G.Wodehouse because the author have most mention in a df with the rating above 4.0

# %%
PGwodehouse= book_eng[(book_eng.authors == 'P.G. Wodehouse')]

# %%
PGwodehouse.to_csv('PGwodehouse.csv')

# %%
import requests
import pandas as pd

# %%
url1 = 'http://127.0.0.1:5000/data/get/%3CPGwodehouse%3E'
r = requests.get(url1)
r_pd = pd.DataFrame(r.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-53-a4802e3ea9bf> in <module>
#       1 url1 = 'http://127.0.0.1:5000/data/get/%3CPGwodehouse%3E'
#       2 r = requests.get(url1)
# ----> 3 r_pd = pd.DataFrame(r.json())
#
# ~/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
r_pd.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-3ef835c77898> in <module>
# ----> 1 r_pd.head()
#
# NameError: name 'r_pd' is not defined

# %%
url2 = 'http://127.0.0.1:5000/data/get/equal/%3CPGwodehouse%3E/%3Cisbn%3E/184159105X'
r = requests.get(url2)
r_pd = pd.DataFrame(r.json())
r_pd.head()

# %%
url3 = 'http://127.0.0.1:5000/Agatha_Christie'
r = requests.get(url3)
r_pd = pd.DataFrame(r.json())

# %%
r_pd.head()

# %%
url4 = 'http://127.0.0.1:5000/data/get/%3CAgatha_Christie%3E/%3Cisbn%3E/0312330871'
r = requests.get(url4)
r_pd = pd.DataFrame(r.json())
r_pd.head()

# %% [markdown]
# # Test Your API Endpoints

# %% [markdown]
# Setelah deployment app kita behasil, kita bisa mencoba mengaksesnya melalui browser, atau jupyter notebook(lebih disarankan). Mari coba beberapa endpoints yang telah kita coba lakukan di lokal.
#
# Untuk catatan, tidak perlu menuliskan port pada url heroku, karena kita sudah mengaturnya pada file `Procfile`

# %%
import requests

import pandas as pd 
heroku_url = 'http://127.0.0.1:5000/Agatha_Christie'
r = requests.get(heroku_url)
r_pd = pd.DataFrame(r.json())
r_pd
